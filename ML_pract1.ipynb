# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('jobs_in_data.csv')

# %%
df
# Out:
#       work_year                 job_title                    job_category  \
# 0          2023      Data DevOps Engineer                Data Engineering
# 1          2023            Data Architect  Data Architecture and Modeling
# 2          2023            Data Architect  Data Architecture and Modeling
# 3          2023            Data Scientist       Data Science and Research
# 4          2023            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350       2021           Data Specialist    Data Management and Strategy
# 9351       2020            Data Scientist       Data Science and Research
# 9352       2021  Principal Data Scientist       Data Science and Research
# 9353       2020            Data Scientist       Data Science and Research
# 9354       2020     Business Data Analyst                   Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9355 non-null   int64
#  1   job_title           9355 non-null   object
#  2   job_category        9355 non-null   object
#  3   salary_currency     9355 non-null   object
#  4   salary              9355 non-null   int64
#  5   salary_in_usd       9355 non-null   int64
#  6   employee_residence  9355 non-null   object
#  7   experience_level    9355 non-null   object
#  8   employment_type     9355 non-null   object
#  9   work_setting        9355 non-null   object
#  10  company_location    9355 non-null   object
#  11  company_size        9355 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 877.2+ KB

# %%
df.head(5)
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
df.isnull().sum()
# Out:
# work_year             0
# job_title             0
# job_category          0
# salary_currency       0
# salary                0
# salary_in_usd         0
# employee_residence    0
# experience_level      0
# employment_type       0
# work_setting          0
# company_location      0
# company_size          0
# dtype: int64

# %%
to_drop = ['work_year','experience_level']

df.drop(to_drop, inplace=True, axis=1)

# %%
df
# Out:
#                      job_title                    job_category  \
# 0         Data DevOps Engineer                Data Engineering
# 1               Data Architect  Data Architecture and Modeling
# 2               Data Architect  Data Architecture and Modeling
# 3               Data Scientist       Data Science and Research
# 4               Data Scientist       Data Science and Research
# ...                        ...                             ...
# 9350           Data Specialist    Data Management and Strategy
# 9351            Data Scientist       Data Science and Research
# 9352  Principal Data Scientist       Data Science and Research
# 9353            Data Scientist       Data Science and Research
# 9354     Business Data Analyst                   Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# 0                EUR   88000          95012            Germany
# 1                USD  186000         186000      United States
# ...

# %%
df.loc[9350]
# Out:
# job_title                          Data Specialist
# job_category          Data Management and Strategy
# salary_currency                                USD
# salary                                      165000
# salary_in_usd                               165000
# employee_residence                   United States
# employment_type                          Full-time
# work_setting                                Remote
# company_location                     United States
# company_size                                     L
# Name: 9350, dtype: object

# %%
df.dtypes.value_counts()
# Out:
# object    8
# int64     2
# Name: count, dtype: int64

# %%
df.loc[1905:, 'salary_currency'].head()
# Out:
# 1905    USD
# 1906    USD
# 1907    USD
# 1908    USD
# 1909    USD
# Name: salary_currency, dtype: object

# %%
df.loc[df.isna().any(axis="columns")]
# Out:
# Empty DataFrame
# Columns: [job_title, job_category, salary_currency, salary, salary_in_usd, employee_residence, employment_type, work_setting, company_location, company_size]
# Index: []

# %%
new_column_names = {
       "job_title": "job_name",
      "Salary_currency": "Sal_in_currency",
     
}
data = df.rename(columns=new_column_names)

# %%
data.columns
# Out:
# Index(['job_name', 'job_category', 'salary_currency', 'salary',
#        'salary_in_usd', 'employee_residence', 'employment_type',
#        'work_setting', 'company_location', 'company_size'],
#       dtype='object')
